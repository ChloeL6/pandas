# %%
import pandas as pd

albums = pd.read_csv('./data/spotify_albums.csv', header=0)

# print(albums.isna().any())
print(albums.shape)           #return total rows and columns
print(albums.tail())          #return the last n row, the name of all columns and the values of each one
albums.head()                 #return the first n row, the name of all columns and the values of each one
# Out:
# (75511, 16)
#           No album_type               artist_id  \
# 75506  75506      album  0S7CCsKpXJ8e1dIstizHw5
# 75507  75507      album  73Vk4dL8kYkbRJxWJDq1wL
# 75508  75508      album  3yW6jTzGjHUUkLvLkjLOVn
# 75509  75509      album  4iudEcmuPlYNdbP3e1bdn1
# 75510  75510      album  023YMawCG3OvACmRjWxLWC
#
#                                        available_markets  \
# 75506  ['AD', 'AE', 'AR', 'AT', 'AU', 'BE', 'BG', 'BH...
# 75507  ['AD', 'AE', 'AR', 'AT', 'AU', 'BE', 'BG', 'BH...
# 75508                                       ['AU', 'NZ']
# 75509  ['AD', 'AE', 'AR', 'AT', 'AU', 'BE', 'BG', 'BH...
# 75510  ['AD', 'AE', 'AR', 'AT', 'AU', 'BE', 'BG', 'BH...
#
#                                            external_urls  \
# 75506  {'spotify': 'https://open.spotify.com/album/4Z...
# 75507  {'spotify': 'https://open.spotify.com/album/4D...
# 75508  {'spotify': 'https://open.spotify.com/album/4P...
# 75509  {'spotify': 'https://open.spotify.com/album/51...
# ...

# %%
artists = pd.read_csv('./data/spotify_artists.csv', header=0)

# artists_null = artists[artists.isnull().any(axis=1)]
# artists_null row #3836 column name

print(artists.shape)          #return total rows and columns
print(artists.tail())         #return the last n row, the name of all columns and the values of each one
artists.head()                #return the first n row, the name of all columns and the values of each one
# Out:
# (56129, 9)
#           No  artist_popularity  followers  \
# 56124  56124                 23       1212
# 56125  56125                 42      57973
# 56126  56126                 38      20870
# 56127  56127                 44      33923
# 56128  56128                 44      42026
#
#                                                   genres  \
# 56124                                   ['chilean rock']
# 56125  ['aggro chileno', 'andean', 'chilean rock', 'l...
# 56126  ['australian alternative rock', 'australian ro...
# 56127  ['australian alternative rock', 'australian ro...
# 56128  ['australian alternative rock', 'australian in...
#
#                            id                   name                track_id  \
# 56124  48YkQQTWzmT248VY8DF7Fv  Profetas y Freneticos  29WK73lMQpLELfHd6PfbjY
# 56125  1OgaghfYd1qr8DFoNrfDNk               Sinergia  0rXhmIYRPIoVYstJdZt4uq
# 56126  7o9kdTx6RmO12iAVVsNehd         The Superjesus  1B7tV3WzEnDUS7wXSKDXk3
# ...

# %%
tracks = pd.read_csv('./data/spotify_tracks.csv', header=0)
# print(tracks.isna().any())
print(tracks.shape)       #return total rows and columns
print(tracks.tail())      #return the last n row, the name of all columns and the values of each one
tracks.head()             #return the first n row, the name of all columns and the values of each one
# Out:
# (101939, 32)
#             No  acousticness                album_id  \
# 101934  101934      0.005640  1M9n4vCmOH4lbcHrpt21Qy
# 101935  101935      0.000406  511p6iaCuK8Sr0BYdpcfkq
# 101936  101936      0.004510  511p6iaCuK8Sr0BYdpcfkq
# 101937  101937      0.333000  7H3Bgvb3hs4vvLwccHDRlr
# 101938  101938      0.028400  3oieBBYbUOve0VpxTCpHr1
#
#                                              analysis_url  \
# 101934  https://api.spotify.com/v1/audio-analysis/4e5w...
# 101935  https://api.spotify.com/v1/audio-analysis/58nH...
# 101936  https://api.spotify.com/v1/audio-analysis/2RDg...
# 101937  https://api.spotify.com/v1/audio-analysis/1pXt...
# 101938  https://api.spotify.com/v1/audio-analysis/6MzG...
#
#                         artists_id  \
# 101934  ['6n3YUZcayLRuAunJUUelvz']
# 101935  ['4iudEcmuPlYNdbP3e1bdn1']
# 101936  ['4iudEcmuPlYNdbP3e1bdn1']
# 101937  ['023YMawCG3OvACmRjWxLWC']
# 101938  ['6OgAO7QYncP5feMijPxBxi']
#
# ...

# %%
albums.loc[10:20, ['name', 'release_date']]
# Out:
#                                                  name release_date
# 10  Beethoven: 6 Bagatelles & Piano Sonatas Nos. 3...   2019-03-01
# 11                                Au Long de la Loire   2019-03-01
# 12                                     I Still Miss U   2019-03-15
# 13                                     Kolmekymppinen         1980
# 14                                              Bruja   2018-04-24
# 15                            Sonatas for two violins   2019-03-01
# 16                                            Sirènes   2019-03-01
# 17                                       Light of Day   2019-03-01
# 18                                   Madame del Campo   2015-08-03
# 19  Beethoven: Piano Concerto No. 2 & Triple Conce...   2019-03-01
# 20                                      Violinsonaten   2019-03-01

# %%
albums[albums.duplicated()]       #find duplicated rows 

albums.drop_duplicates(inplace=True)

print(f'albums shape: {albums.shape}')
# Out:
# albums shape: (75511, 16)

# %%
artists[artists.duplicated()]

artists.drop_duplicates(inplace=True)

print(f'artists shape: {artists.shape}')
# Out:
# artists shape: (56129, 9)

# %%
tracks[tracks.duplicated()]

tracks.drop_duplicates(inplace=True)

print(f'tracks shape: {tracks.shape}')
# Out:
# tracks shape: (101939, 32)

# %%
# artists_dropcols = artists.T.drop_duplicates().T
# artists_dropcols.shape

# albums_dropcols = albums.T.drop_duplicates().T
# albums_dropcols.shape

# tracks_dropcols = tracks.T.drop_duplicates().T
# tracks_dropcols.shape
# Out:
# (101939, 31)

# %%
import numpy as np

artists = pd.read_csv('./data/spotify_artists.csv', header=0)

# length = artists['genres'].apply(len) check the length of element

# #replace empty list [] with nan 
def replace_empty_list(value):
    if len(value) == 2:
        return np.nan
    else:
        return value

artists['genres']= artists['genres'].map(replace_empty_list)

artists.head(5)
# Out:
#    No  artist_popularity  followers  \
# 0   0                 44      23230
# 1   1                 22        313
# 2   2                 26       1596
# 3   3                 31        149
# 4   4                 21         11
#
#                                               genres                      id  \
# 0  ['sertanejo', 'sertanejo pop', 'sertanejo trad...  4mGnpjhqgx4RUdsIJiURdo
# 1                                                NaN  1dLnVku4VQUOLswwDFvRc9
# 2                                ['danish pop rock']  6YVY310fjfUzKi8hiqR7iK
# 3                             ['uk alternative pop']  2VElyouiCfoYPDJluzwJwK
# 4                                 ['french baroque']  4agVy03qW8juSysCTUOuDI
#
#                   name                track_id track_name_prev    type
# 0        Juliano Cezar  0wmDmAILuW9e2aRttkl4aC         track_9  artist
# 1       The Grenadines  4wqwj0gA8qPZKLl5WVqXml        track_30  artist
# ...

# %%
cols = list(tracks.columns)       #print name of columns in Tracks
print(cols)

tracks.drop(labels='lyrics', axis=1, inplace=True)  
print(list(tracks.columns))
# Out:
# ['No', 'acousticness', 'album_id', 'analysis_url', 'artists_id', 'available_markets', 'country', 'danceability', 'disc_number', 'duration_ms', 'energy', 'href', 'id', 'instrumentalness', 'key', 'liveness', 'loudness', 'lyrics', 'mode', 'name', 'playlist', 'popularity', 'preview_url', 'speechiness', 'tempo', 'time_signature', 'track_href', 'track_name_prev', 'track_number', 'uri', 'valence', 'type']
# ['No', 'acousticness', 'album_id', 'analysis_url', 'artists_id', 'available_markets', 'country', 'danceability', 'disc_number', 'duration_ms', 'energy', 'href', 'id', 'instrumentalness', 'key', 'liveness', 'loudness', 'mode', 'name', 'playlist', 'popularity', 'preview_url', 'speechiness', 'tempo', 'time_signature', 'track_href', 'track_name_prev', 'track_number', 'uri', 'valence', 'type']

# %%
# artists.get('artist_id', default='no_id') #get artist_id in in artist dataframe, if not, return no_id

print(f'artist file: \n {list(artists.columns)}')
print(f'albums file: \n {list(albums.columns)}')
# Out:
# artist file:
#  ['No', 'artist_popularity', 'followers', 'genres', 'id', 'name', 'track_id', 'track_name_prev', 'type']
# albums file:
#  ['No', 'album_type', 'artist_id', 'available_markets', 'external_urls', 'href', 'id', 'images', 'name', 'release_date', 'release_date_precision', 'total_tracks', 'track_id', 'track_name_prev', 'uri', 'type']

# %%
#join artist to albums
#not every artist has albums
# Join artists and albums on the artist ID. Print the head() and shape of the resulting DataFrame.

# Since some artist does not have albums, merge() with how='inner' returns a dataframe returns matched rows between artists and albums
#if artist does not has album, or the album does not has matched artist, that rows will be discarded. 
artists_albums = artists.merge(albums.set_index('No'), left_on='id', right_on='artist_id', how='inner', suffixes=['_art', '_alb']).drop_duplicates()
print(artists_albums.shape)
artists_albums.head(5)
# Out:
# (74991, 24)
#    No  artist_popularity  followers  \
# 0   0                 44      23230
# 1   0                 44      23230
# 2   1                 22        313
# 3   2                 26       1596
# 4   3                 31        149
#
#                                               genres                  id_art  \
# 0  ['sertanejo', 'sertanejo pop', 'sertanejo trad...  4mGnpjhqgx4RUdsIJiURdo
# 1  ['sertanejo', 'sertanejo pop', 'sertanejo trad...  4mGnpjhqgx4RUdsIJiURdo
# 2                                                NaN  1dLnVku4VQUOLswwDFvRc9
# 3                                ['danish pop rock']  6YVY310fjfUzKi8hiqR7iK
# 4                             ['uk alternative pop']  2VElyouiCfoYPDJluzwJwK
#
#          name_art            track_id_art track_name_prev_art type_art  \
# 0   Juliano Cezar  0wmDmAILuW9e2aRttkl4aC             track_9   artist
# 1   Juliano Cezar  0wmDmAILuW9e2aRttkl4aC             track_9   artist
# ...

# %%
print(f'albums: \n {albums.columns.to_list()}')
print(f'tracks: \n {list(tracks.columns)}')

#since some albums does not include in tracks, merge() with how='inner' will only return the matched rows between two dataframes
albums_tracks = albums.merge(tracks, left_on='id', right_on='album_id', how='inner')

print(f'albums: \n {albums.shape}')
print(f'tracks: \n {tracks.shape}')
print(albums_tracks.shape)
albums_tracks.head()
# Out:
# albums:
#  ['No', 'album_type', 'artist_id', 'available_markets', 'external_urls', 'href', 'id', 'images', 'name', 'release_date', 'release_date_precision', 'total_tracks', 'track_id', 'track_name_prev', 'uri', 'type']
# tracks:
#  ['No', 'acousticness', 'album_id', 'analysis_url', 'artists_id', 'available_markets', 'country', 'danceability', 'disc_number', 'duration_ms', 'energy', 'href', 'id', 'instrumentalness', 'key', 'liveness', 'loudness', 'mode', 'name', 'playlist', 'popularity', 'preview_url', 'speechiness', 'tempo', 'time_signature', 'track_href', 'track_name_prev', 'track_number', 'uri', 'valence', 'type']
# albums:
#  (75511, 16)
# tracks:
#  (101939, 31)
# (101939, 47)
#    No_x album_type               artist_id  \
# 0     0     single  3DiDSECUqqY1AuBP8qtaIa
# 1     1      album  6s1pCNXcbdtQJlsnM1hRIA
# 2     2     single  5YjfNaHq05WrwldRe1QSBc
# 3     3     single  2G9Vc16JCpnZmK4uGH46Fa
# 4     4     single  2dwM9OcE4c3Ph1UBINSodx
#
# ...

# %%
high_appearance = artists['name'].value_counts()
print(high_appearance)
print(f'Artists appear the most is: Haze and Sasha')
# Out:
# Haze                  5
# Sasha                 5
# Elias                 4
# Karina                4
# Alex                  4
#                      ..
# Steuerfreimoney       1
# Avery Florence        1
# Ian van Dahl          1
# Bikini Kill           1
# Something For Kate    1
# Name: name, Length: 55505, dtype: int64
# Artists appear the most is: Haze and Sasha

# %%
# group_rank = artists.groupby(by='name').artist_popularity.max()
# top_group_rank = group_rank.sort_values(ascending=False)
# top_group_rank.head(10)

top_rank = artists.nlargest(n=10, columns=['artist_popularity'])
top_rank[['name', 'artist_popularity']]
# Out:
#                 name  artist_popularity
# 42872  Ariana Grande                100
# 53392          Drake                 98
# 49775    Post Malone                 96
# 49695     Juice WRLD                 95
# 52306          Ozuna                 95
# 53406         Khalid                 95
# 55822   XXXTENTACION                 95
# 39126          Queen                 94
# 49320   Travis Scott                 94
# 52280       Anuel Aa                 94
